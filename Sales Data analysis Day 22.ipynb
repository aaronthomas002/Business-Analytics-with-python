# %%
import pandas as pd

# %%
x=pd.read_csv("Supermarket.csv")

# %%
x
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
a=x.loc[1,"Unitprice"]
a
# Out:
# 15.28

# %%
new_data=[]
for a in x.index:
    new_data.append(x.loc[a,"Unitprice"])
max(new_data)
# Out:
# 99.96

# %%
new_data=[]
for a in x.index:
    new_data.append(x.loc[a,"Unitprice"])
min(new_data)
# Out:
# 10.08

# %%
new_data=[]
for a in x.index:
    new_data.append(x.loc[a,"Unitprice"])
sum(new_data)/len(new_data)
# Out:
# 55.67212999999998

# %%
new_data=[]
for a in x.index:
    new_data.append(x.loc[a,"Quantity"])
max(new_data)
# Out:
# 10

# %%
new_data=[]
for a in x.index:
    new_data.append(x.loc[a,"Quantity"])
min(new_data)
# Out:
# 1

# %%
new_data=[]
for a in x.index:
    new_data.append(x.loc[a,"Quantity"])
b=sum(new_data)/len(new_data)
print(b)
# Out:
# 5.51

# %%
new_data=[]
for a in x.index:
    if (x.loc[a,"Productline"]=="Health and beauty"):
        new_data.append(x.loc[a,"Quantity"])
max(new_data)
# Out:
# 10

# %%
min(new_data)
# Out:
# 1

# %%
b=sum(new_data)/len(new_data)
b
# Out:
# 5.618421052631579

# %%
new_data=[]
for a in x.index:
    if (x.loc[a,"Productline"]=="Health and beauty"):
        new_data.append(x.loc[a,"Unitprice"])
max(new_data)
# Out:
# 99.96

# %%
min(new_data)
# Out:
# 10.08

# %%
b=sum(new_data)/len(new_data)
b
# Out:
# 54.85447368421053

# %%
new_data=[]
for a in x.index:
    if (x.loc[a,"Productline"]=="Electronic accessories"):
        new_data.append(x.loc[a,"Quantity"])
max(new_data)
# Out:
# 10

# %%
min(new_data)
# Out:
# 1

# %%
b=sum(new_data)/len(new_data)
b
# Out:
# 5.711764705882353

# %%
new_data=[]
for a in x.index:
    if(x.loc[a,"Productline"])=="Health and beauty":
        if (x.loc[a,"Quantity"])==10:
            new_data.append(x.loc[a,"InvoiceID"])
print(new_data)
# Out:
# ['829-34-3910', '877-22-3308', '766-85-7061', '280-17-4359', '338-65-2210', '875-46-5808', '157-13-5295', '585-03-5943', '400-45-1220', '725-56-0833', '244-08-0162', '628-90-8624', '188-55-0967', '648-94-3045', '689-05-1884', '607-65-2441', '450-42-3339']

# %%
new_data=[]
for a in x.index:
    if(x.loc[a,"Productline"])=="Health and beauty":
        if (x.loc[a,"Quantity"])==1:
            new_data.append(x.loc[a,"InvoiceID"])
print(new_data)
# Out:
# ['382-03-4532', '512-91-0811', '573-10-3877', '622-20-1945', '885-17-6250', '268-03-6164', '186-09-3669', '390-80-5128', '296-11-7041', '568-88-3448', '343-87-0864', '359-94-5395', '559-61-5987', '528-14-9470', '233-67-5758']

# %%
new_data=[]
for a in x.index:
    if(x.loc[a,"Gender"]=="Male") and (x.loc[a,"Productline"]=="Health and beauty"):
         new_data.append(x.loc[a,"InvoiceID"])
len(new_data)
# Out:
# 88

# %%
new_data=[]
for a in x.index:
    if(x.loc[a,"Gender"]=="Female") and (x.loc[a,"Productline"]=="Fashion accessories"):
         new_data.append(x.loc[a,"InvoiceID"])
len(new_data)
# Out:
# 96

# %%
new_data=[]
for a in x.index:
    if(x.loc[a,"Gender"]=="Female") and (x.loc[a,"Productline"]=="Fashion accessories") or (x.loc[a,"Productline"]=="Sports and travel"):
         new_data.append(x.loc[a,"InvoiceID"])
len(new_data)
# Out:
# 262

# %%
import matplotlib.pyplot as plt

# %%
new_data=[]
for a in x.index:
    if(x.loc[a,"Gender"]=="Male"):
        new_data.append(x.loc[a,"Quantity"])
new_data
# Out:
# [7,
#  8,
#  7,
#  7,
#  4,
#  10,
#  6,
#  3,
#  5,
#  3,
#  2,
#  5,
#  3,
#  1,
#  9,
#  5,
#  9,
#  8,
#  2,
#  5,
#  8,
#  2,
#  2,
#  9,
#  6,
#  7,
#  1,
#  2,
#  2,
#  8,
#  6,
#  6,
#  10,
#  4,
#  10,
#  10,
#  10,
#  10,
#  9,
#  9,
#  8,
#  5,
#  5,
#  7,
#  1,
#  9,
#  1,
#  1,
#  10,
#  3,
#  6,
#  1,
#  9,
#  6,
#  7,
#  10,
#  6,
#  6,
#  10,
#  9,
#  5,
#  1,
#  2,
#  7,
#  9,
#  8,
#  6,
#  3,
#  10,
#  8,
#  10,
#  4,
#  8,
#  8,
#  7,
#  9,
#  5,
#  1,
#  5,
#  9,
#  6,
#  1,
#  7,
#  2,
#  10,
#  8,
#  10,
#  10,
#  6,
#  7,
#  5,
#  5,
#  8,
#  6,
#  8,
#  9,
#  8,
#  6,
#  3,
#  7,
#  8,
#  10,
#  8,
#  3,
#  4,
#  1,
#  4,
#  5,
#  2,
#  4,
#  7,
#  10,
#  5,
#  9,
#  5,
#  3,
#  1,
#  8,
#  6,
#  7,
#  5,
#  2,
#  9,
#  4,
#  4,
#  10,
#  5,
#  1,
#  9,
#  2,
#  2,
#  4,
#  8,
#  8,
#  5,
#  4,
#  7,
#  9,
#  10,
#  4,
#  8,
#  4,
#  1,
#  6,
#  4,
#  4,
#  1,
#  4,
#  4,
#  7,
#  10,
#  10,
#  1,
#  6,
#  5,
#  1,
#  10,
#  7,
#  10,
#  4,
#  6,
#  4,
#  2,
# ...

# %%
mew_data=[]
for a in x.index:
    if(x.loc[a,"Gender"]=="Male"):
        mew_data.append(x.loc[a,"Tax"])
mew_data
# Out:
# [16.2155,
#  23.288,
#  30.2085,
#  29.8865,
#  5.102,
#  21.595,
#  21.783,
#  8.2005,
#  21.51,
#  13.197,
#  3.32,
#  8.64,
#  13.2945,
#  1.676,
#  11.2005,
#  23.5325,
#  35.1315,
#  33.512,
#  9.658,
#  15.655,
#  12.048,
#  5.611,
#  1.537,
#  25.5105,
#  5.679,
#  31.99,
#  0.7715,
#  1.616,
#  4.434,
#  35.84,
#  9.183,
#  16.719,
#  7.905,
#  15.148,
#  7.935,
#  39.385,
#  44.74,
#  31.06,
#  33.6015,
#  22.068,
#  7.7,
#  12.2275,
#  19.13,
#  17.283,
#  2.1235,
#  28.962,
#  4.4875,
#  4.858,
#  43.935,
#  7.9125,
#  24.81,
#  2.4355,
#  35.3475,
#  17.478,
#  10.6225,
#  44.335,
#  8.214,
#  18.639,
#  40.985,
#  26.1315,
#  5.485,
#  2.568,
#  5.344,
#  19.992,
#  44.982,
#  25.564,
#  26.235,
#  13.533,
#  25.955,
#  29.0,
#  45.25,
#  13.228,
#  28.744,
#  12.984,
#  12.096,
#  37.458,
#  23.0725,
#  3.6085,
#  12.57,
#  43.749,
#  28.017,
#  3.1845,
#  16.0265,
#  7.64,
#  19.95,
#  17.028,
#  47.79,
#  49.49,
#  15.384,
#  24.332,
#  17.5025,
#  20.0125,
#  8.34,
# ...

# %%
plt.scatter(mew_data,new_data)

# %%
new_data=[]
for a in x.index:
    if(x.loc[a,"City"]=="Yangon"):
        new_data.append(x.loc[a,"Tax"])
sum(new_data)
# Out:
# 5057.160500000002

# %%
new_data=[]
for a in x.index:
    if (x.loc[a,"City"]=="Yangon"):
        new_data.append(x.loc[a,"Quantity"])
sum(new_data)
# Out:
# 1859

# %%
new_data=[]
for a in x.index:
    if (x.loc[a,"City"]=="Mandalay"):
        new_data.append(x.loc[a,"Quantity"])
sum(new_data)
# Out:
# 1820

# %%
new_data=[]
for a in x.index:
        new_data.append(x.loc[a,"Tax"])
new_data
# Out:
# [26.1415,
#  3.82,
#  16.2155,
#  23.288,
#  30.2085,
#  29.8865,
#  20.652,
#  36.78,
#  3.626,
#  8.226,
#  2.896,
#  5.102,
#  11.7375,
#  21.595,
#  35.69,
#  28.116,
#  24.1255,
#  21.783,
#  8.2005,
#  4.03,
#  21.51,
#  13.197,
#  3.32,
#  8.64,
#  13.2945,
#  21.036,
#  1.676,
#  8.767,
#  22.09,
#  11.2005,
#  23.5325,
#  35.1315,
#  33.512,
#  9.658,
#  19.884,
#  3.406,
#  15.655,
#  27.396,
#  21.968,
#  12.048,
#  4.336,
#  5.611,
#  20.736,
#  39.48,
#  1.537,
#  18.792,
#  25.5105,
#  9.0045,
#  5.679,
#  41.315,
#  31.99,
#  11.1475,
#  3.574,
#  0.7715,
#  1.616,
#  34.392,
#  4.434,
#  35.84,
#  36.175,
#  9.183,
#  3.711,
#  16.719,
#  24.7815,
#  7.905,
#  15.148,
#  7.935,
#  3.347,
#  29.283,
#  39.385,
#  0.9165,
#  44.74,
#  31.06,
#  7.278,
#  22.773,
#  33.6015,
#  20.825,
#  22.068,
#  9.0045,
#  39.155,
#  5.095,
#  29.757,
#  14.502,
#  7.7,
#  16.072,
#  12.2275,
#  29.071,
#  19.13,
#  17.283,
#  2.1235,
#  23.097,
#  9.476,
#  22.43,
#  7.693,
# ...

# %%
mew_data=[]
for a in x.index:
        mew_data.append(x.loc[a,"Unitprice"])
mew_data
# Out:
# [74.69,
#  15.28,
#  46.33,
#  58.22,
#  86.31,
#  85.39,
#  68.84,
#  73.56,
#  36.26,
#  54.84,
#  14.48,
#  25.51,
#  46.95,
#  43.19,
#  71.38,
#  93.72,
#  68.93,
#  72.61,
#  54.67,
#  40.3,
#  86.04,
#  87.98,
#  33.2,
#  34.56,
#  88.63,
#  52.59,
#  33.52,
#  87.67,
#  88.36,
#  24.89,
#  94.13,
#  78.07,
#  83.78,
#  96.58,
#  99.42,
#  68.12,
#  62.62,
#  60.88,
#  54.92,
#  30.12,
#  86.72,
#  56.11,
#  69.12,
#  98.7,
#  15.37,
#  93.96,
#  56.69,
#  20.01,
#  18.93,
#  82.63,
#  91.4,
#  44.59,
#  17.87,
#  15.43,
#  16.16,
#  85.98,
#  44.34,
#  89.6,
#  72.35,
#  30.61,
#  24.74,
#  55.73,
#  55.07,
#  15.81,
#  75.74,
#  15.87,
#  33.47,
#  97.61,
#  78.77,
#  18.33,
#  89.48,
#  62.12,
#  48.52,
#  75.91,
#  74.67,
#  41.65,
#  49.04,
#  20.01,
#  78.31,
#  20.38,
#  99.19,
#  96.68,
#  19.25,
#  80.36,
#  48.91,
#  83.06,
#  76.52,
#  49.38,
#  42.47,
#  76.99,
#  47.38,
#  44.86,
#  21.98,
#  64.36,
#  89.75,
#  97.16,
#  87.87,
#  12.45,
#  52.75,
#  82.7,
# ...

# %%
plt.scatter(new_data,mew_data)

# %%
new_data=[]
for a in x.index:
    if (x.loc[a,"City"]=="Yangon") and (x.loc[a,"Branch"]=="A"):
        new_data.append(x.loc[a,"Quantity"])
sum(new_data)
# Out:
# 1859

# %%
dew_data=[]
for a in x.index:
    if (x.loc[a,"City"]=="Naypyitaw") and (x.loc[a,"Branch"]=="C"):
        dew_data.append(x.loc[a,"Quantity"])
sum(dew_data)
# Out:
# 1831

# %%
if sum(new_data)>sum(dew_data):
    print("Yangon")
else:
    print("Naypitaw")
# Out:
# Yangon

# %%
new_data=[]
for a in x.index:
    new_data.append(x.loc[a,"gross_iincome"])
max(new_data)
# Out:
# 49.65

# %%
new_data=[]
for a in x.index:
    if x.loc[a,"gross_iincome"]==49.65:
        new_data.append(x.loc[a,"Date"])
len(new_data)
# Out:
# 1

# %%
new_data=[]
for a in x.index:
    if x.loc[a,"gross_iincome"]==49.65:
        new_data.append(x.loc[a,"Branch"])
len(new_data)
# Out:
# 1

# %%
new_data=[]
for a in x.index:
    if x.loc[a,"gross_iincome"]==49.65:
        new_data.append(x.loc[a,"InvoiceID"])
len(new_data)
# Out:
# 1

# %%
new_data=[]
for a in x.index:
    if x.loc[a,"gross_iincome"]==49.65:
        new_data.append(x.loc[a,"Gender"])
print(new_data)
# Out:
# ['Female']

# %%
new_data=[]
for a in x.index:
    if x.loc[a,"gross_iincome"]==49.65:
        new_data.append(x.loc[a,"Customertype"])
print(new_data)
# Out:
# ['Member']

# %%
dew_data=[]
for a in x.index:
    if (x.loc[a,"gross_iincome"]==49.65)and(x.loc[a,"gross_margin_percentage"]==4.761905):
        dew_data.append(x.loc[a,"Productline"])
dew_data
# Out:
# []

# %%
new_data=[]
for a in x.index:
    new_data.append(x.loc[a,"gross_iincome"])
min(new_data)
# Out:
# 0.5085

# %%
new_data=[]
for a in x.index:
    if (x.loc[a,"gross_iincome"]==0.5085):
        new_data.append(x.loc[a,"InvoiceID"])
print(new_data)
# Out:
# ['784-21-9238']
