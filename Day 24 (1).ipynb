# %%
import pandas as pd

# %%
df=pd.read_excel("Supermarket.xlsx")

# %%
df
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
for i in df.index:
    print(df.Branch[i])
# Out:
# A
# C
# A
# A
# A
# C
# A
# C
# A
# B
# B
# B
# A
# A
# A
# B
# A
# A
# A
# B
# C
# B
# B
# A
# A
# A
# B
# A
# B
# A
# B
# B
# B
# A
# C
# C
# A
# A
# C
# B
# B
# C
# B
# C
# C
# B
# B
# B
# B
# C
# C
# A
# B
# C
# B
# C
# A
# A
# A
# C
# C
# C
# B
# A
# B
# A
# C
# B
# A
# A
# C
# C
# B
# C
# A
# C
# C
# A
# C
# C
# C
# B
# C
# C
# C
# C
# C
# A
# A
# B
# C
# C
# A
# B
# C
# A
# B
# C
# A
# B
# C
# C
# C
# A
# B
# A
# C
# A
# C
# C
# B
# C
# B
# A
# C
# C
# B
# B
# A
# B
# A
# C
# B
# C
# B
# A
# A
# C
# C
# B
# B
# A
# B
# B
# C
# C
# A
# A
# B
# A
# C
# C
# C
# C
# A
# C
# A
# C
# B
# A
# B
# C
# A
# C
# C
# A
# B
# B
# B
# B
# C
# A
# A
# C
# B
# B
# C
# A
# A
# A
# A
# B
# C
# B
# B
# A
# A
# C
# A
# C
# C
# C
# A
# C
# A
# B
# B
# B
# A
# C
# B
# B
# C
# B
# A
# C
# C
# A
# C
# C
# C
# B
# C
# B
# B
# A
# C
# C
# B
# B
# A
# C
# B
# B
# B
# A
# B
# A
# B
# B
# B
# B
# C
# C
# A
# C
# B
# C
# B
# A
# B
# B
# B
# B
# A
# A
# C
# C
# B
# A
# A
# A
# C
# A
# B
# A
# B
# A
# A
# B
# ...

# %%
df.groupby("Quantity").count()
# Out:
#            No  InvoiceID  Branch  City  Customertype  Gender  Productline  \
# Quantity
# 1         112        112     112   112           112     112          112
# 2          91         91      91    91            91      91           91
# 3          90         90      90    90            90      90           90
# 4         109        109     109   109           109     109          109
# 5         102        102     102   102           102     102          102
# 6          98         98      98    98            98      98           98
# 7         102        102     102   102           102     102          102
# 8          85         85      85    85            85      85           85
# 9          92         92      92    92            92      92           92
# 10        119        119     119   119           119     119          119
#
#           Unitprice  Tax  Total  Date  Time  Payment  cogs  \
# Quantity
# 1               112  112    112   112   112      112   112
# ...

# %%
df.Unitprice()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b9cb813140d3> in <module>
# ----> 1 df.Unitprice()
#
# TypeError: 'Series' object is not callable

# %%
df.groupby("Productline").mean()
# Out:
#                                 No  Unitprice  Quantity        Tax  \
# Productline
# Electronic accessories  515.758824  53.551588  5.711765  15.220597
# Fashion accessories     508.365169  57.153652  5.067416  14.528062
# Food and beverages      506.873563  56.008851  5.471264  15.365310
# Health and beauty       495.532895  54.854474  5.618421  15.411572
# Home and lifestyle      497.087500  55.316937  5.693750  16.030331
# Sports and travel       477.596386  56.993253  5.542169  15.812630
#
#                              Total        cogs  gross_margin_percentage  \
# Productline
# Electronic accessories  319.632538  304.411941                 4.761905
# Fashion accessories     305.089298  290.561236                 4.761905
# Food and beverages      322.671517  307.306207                 4.761905
# Health and beauty       323.643020  308.231447                 4.761905
# Home and lifestyle      336.636956  320.606625                 4.761905
# ...

# %%
df.loc[df["City"]=="Yangon"]
# Out:
#        No    InvoiceID Branch    City Customertype  Gender  \
# 0       1  750-67-8428      A  Yangon       Member  Female
# 2       3  631-41-3108      A  Yangon       Normal    Male
# 3       4  123-19-1176      A  Yangon       Member    Male
# 4       5  373-73-7910      A  Yangon       Normal    Male
# 6       7  355-53-5943      A  Yangon       Member  Female
# ..    ...          ...    ...     ...          ...     ...
# 990   991  886-18-2897      A  Yangon       Normal  Female
# 992   993  745-74-0715      A  Yangon       Normal    Male
# 997   998  727-02-1313      A  Yangon       Member    Male
# 998   999  347-56-2442      A  Yangon       Normal    Male
# 999  1000  849-09-3807      A  Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax     Total  \
# 0         Health and beauty      74.69         7  26.1415  548.9715
# 2        Home and lifestyle      46.33         7  16.2155  340.5255
# ...

# %%
df.loc[df["Gender"]=="Female"]
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 6       7  355-53-5943      A     Yangon       Member  Female
# 7       8  315-22-5665      C  Naypyitaw       Normal  Female
# 8       9  665-32-9167      A     Yangon       Member  Female
# ..    ...          ...    ...        ...          ...     ...
# 990   991  886-18-2897      A     Yangon       Normal  Female
# 991   992  602-16-6955      B   Mandalay       Normal  Female
# 994   995  652-49-6720      C  Naypyitaw       Member  Female
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
df.Unitprice.loc[df["Productline"]=="Health and beauty"].min()
# Out:
# 10.08

# %%
df.Unitprice.loc[df["Productline"]=="Health and beauty"].max()
# Out:
# 99.96

# %%
df.Unitprice.loc[df["Productline"]=="Health and beauty"].mean()
# Out:
# 54.85447368421053

# %%
df['Quantity'].loc[df['Productline'] == "Electronic accessories"].max()
# Out:
# 10

# %%
df['Quantity'].loc[df['Productline'] == "Electronic accessories"].min()
# Out:
# 1

# %%
df['Quantity'].loc[df['Productline'] == "Electronic accessories"].mean()
# Out:
# 5.711764705882353

# %%
x=df["Gender"].loc[df['Productline'] == "Health and beauty"]

# %%
x
# Out:
# 0      Female
# 3        Male
# 8      Female
# 14     Female
# 16     Female
#         ...
# 983      Male
# 986    Female
# 987      Male
# 989      Male
# 995      Male
# Name: Gender, Length: 152, dtype: object

# %%
df.loc[(df['Productline'] == "Health and beauty") & (df['Gender'] == "Male") ]
# Out:
#       No    InvoiceID Branch       City Customertype Gender  \
# 3      4  123-19-1176      A     Yangon       Member   Male
# 21    22  371-85-5789      B   Mandalay       Normal   Male
# 29    30  848-62-7243      A     Yangon       Normal   Male
# 33    34  595-11-5460      A     Yangon       Normal   Male
# 44    45  617-15-4209      C  Naypyitaw       Member   Male
# ..   ...          ...    ...        ...          ...    ...
# 981  982  809-46-1866      A     Yangon       Normal   Male
# 983  984  148-41-7930      C  Naypyitaw       Normal   Male
# 987  988  552-44-5977      B   Mandalay       Member   Male
# 989  990  430-53-4718      B   Mandalay       Member   Male
# 995  996  233-67-5758      C  Naypyitaw       Normal   Male
#
#            Productline  Unitprice  Quantity      Tax     Total  \
# 3    Health and beauty      58.22         8  23.2880  489.0480
# 21   Health and beauty      87.98         3  13.1970  277.1370
# ...

# %%
df.loc[(df['Productline'] == "Health and beauty") & (df['Gender']== "Female") ]
# Out:
#       No    InvoiceID Branch       City Customertype  Gender  \
# 0      1  750-67-8428      A     Yangon       Member  Female
# 8      9  665-32-9167      A     Yangon       Member  Female
# 14    15  829-34-3910      A     Yangon       Normal  Female
# 16    17  656-95-9349      A     Yangon       Member  Female
# 38    39  333-73-7901      C  Naypyitaw       Normal  Female
# ..   ...          ...    ...        ...          ...     ...
# 927  928  397-25-8725      A     Yangon       Member  Female
# 936  937  433-08-7822      C  Naypyitaw       Normal  Female
# 938  939  131-70-8179      A     Yangon       Member  Female
# 968  969  605-03-2706      A     Yangon       Normal  Female
# 986  987  764-44-8999      B   Mandalay       Normal  Female
#
#            Productline  Unitprice  Quantity      Tax     Total  \
# 0    Health and beauty      74.69         7  26.1415  548.9715
# 8    Health and beauty      36.26         2   3.6260   76.1460
# ...

# %%
df.loc[(df['Productline'] == "Health and beauty") & (df['Gender'] == "Male") ].count()
# Out:
# No                         88
# InvoiceID                  88
# Branch                     88
# City                       88
# Customertype               88
# Gender                     88
# Productline                88
# Unitprice                  88
# Quantity                   88
# Tax                        88
# Total                      88
# Date                       88
# Time                       88
# Payment                    88
# cogs                       88
# gross_margin_percentage    88
# gross_iincome              88
# Rating                     88
# dtype: int64

# %%
df.loc[(df['Productline'] == "Fashion accessories") & (df['Gender'] == "Female") ].count()
# Out:
# No                         96
# InvoiceID                  96
# Branch                     96
# City                       96
# Customertype               96
# Gender                     96
# Productline                96
# Unitprice                  96
# Quantity                   96
# Tax                        96
# Total                      96
# Date                       96
# Time                       96
# Payment                    96
# cogs                       96
# gross_margin_percentage    96
# gross_iincome              96
# Rating                     96
# dtype: int64

# %%
df.loc[(df['Productline'] == "Fashion accessories") & (df['Gender'] == "Female") | (df['Productline'] == "Sports and travel") ].count()
# Out:
# No                         262
# InvoiceID                  262
# Branch                     262
# City                       262
# Customertype               262
# Gender                     262
# Productline                262
# Unitprice                  262
# Quantity                   262
# Tax                        262
# Total                      262
# Date                       262
# Time                       262
# Payment                    262
# cogs                       262
# gross_margin_percentage    262
# gross_iincome              262
# Rating                     262
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
x=df["Tax"].loc[df['Gender'] == "Male"]
x
# Out:
# 2      16.2155
# 3      23.2880
# 4      30.2085
# 5      29.8865
# 11      5.1020
#         ...
# 992     5.8030
# 993     8.7450
# 995     2.0175
# 997     1.5920
# 998     3.2910
# Name: Tax, Length: 499, dtype: float64

# %%
y=df["Quantity"].loc[df['Gender'] == "Male"]
y
# Out:
# 2       7
# 3       8
# 4       7
# 5       7
# 11      4
#        ..
# 992     2
# 993    10
# 995     1
# 997     1
# 998     1
# Name: Quantity, Length: 499, dtype: int64

# %%
plt.scatter(x,y)

# %%
totx=df["Tax"].loc[df['City'] == "Yangon"]
totx
# Out:
# 0      26.1415
# 2      16.2155
# 3      23.2880
# 4      30.2085
# 6      20.6520
#         ...
# 990    14.1400
# 992     5.8030
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Name: Tax, Length: 340, dtype: float64

# %%
totx.sum()
# Out:
# 5057.1605

# %%
a=df["Quantity"].loc[df["City"]=="Yangon"]
print(a)
# Out:
# 0      7
# 2      7
# 3      8
# 4      7
# 6      6
#       ..
# 990    5
# 992    2
# 997    1
# 998    1
# 999    7
# Name: Quantity, Length: 340, dtype: int64

# %%
a.sum()
# Out:
# 1859

# %%
a=df["Quantity"].loc[df["City"]=="Mandalay"]
print(a)
# Out:
# 9       3
# 10      4
# 11      4
# 15      6
# 19      2
#        ..
# 987     8
# 989     8
# 991    10
# 993    10
# 996    10
# Name: Quantity, Length: 332, dtype: int64

# %%
a.sum()
# Out:
# 1820

# %%
BranchA = df["Quantity"].loc[(df['City'] == "Mandalay") & (df['Branch'] == "A") ]
BranchA
# Out:
# Series([], Name: Quantity, dtype: int64)

# %%
BranchB = df["Quantity"].loc[(df['City'] == "Mandalay") & (df['Branch'] == "B") ]
BranchB
# Out:
# 9       3
# 10      4
# 11      4
# 15      6
# 19      2
#        ..
# 987     8
# 989     8
# 991    10
# 993    10
# 996    10
# Name: Quantity, Length: 332, dtype: int64

# %%
BranchC = df["Quantity"].loc[(df['City'] == "Mandalay") & (df['Branch'] == "F") ]
BranchC
# Out:
# Series([], Name: Quantity, dtype: int64)

# %%
BranchA.sum()
# Out:
# 0

# %%
BranchB.sum()
# Out:
# 1820

# %%
BranchC.sum()
# Out:
# 0

# %%
df.head()
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
#
#               Productline  Unitprice  Quantity      Tax     Total  \
# 0       Health and beauty      74.69         7  26.1415  548.9715
# 1  Electronic accessories      15.28         5   3.8200   80.2200
# 2      Home and lifestyle      46.33         7  16.2155  340.5255
# 3       Health and beauty      58.22         8  23.2880  489.0480
# 4       Sports and travel      86.31         7  30.2085  634.3785
#
#                   Date      Time      Payment    cogs  \
# 0  2019-05-01 00:00:00  13:08:00      Ewallet  522.83
# 1  2019-08-03 00:00:00  10:29:00         Cash   76.40
# ...

# %%
a=df["Quantity"].loc[(df['Productline'] == "Health and beauty")]
b=df["Quantity"].loc[(df['Productline'] == "Electronic accessories")]
c=df["Quantity"].loc[(df['Productline'] == "Home and lifestyle")]
d=df["Quantity"].loc[(df['Productline'] == "Sports and travel")]

# %%
a.sum()
# Out:
# 854

# %%
b.sum()
# Out:
# 971

# %%
c.sum()
# Out:
# 911

# %%
d.sum()
# Out:
# 920

# %%
x=df.Tax

# %%
x
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3      23.2880
# 4      30.2085
#         ...
# 995     2.0175
# 996    48.6900
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Name: Tax, Length: 1000, dtype: float64

# %%
y=df.Unitprice

# %%
plt.scatter(x,y)

# %%
df.gross_iincome.max()
# Out:
# 49.65

# %%
for x in df.index:
    if df.gross_iincome[x]==49.65:
        print(df.Branch[x]) 
        print(df.InvoiceID[x])
# Out:
# C
# 860-79-0874

# %%
for x in df.index:
    if df.gross_iincome[x]==49.65:
        print(df.Gender[x])
# Out:
# Female

# %%
for x in df.index:
    if df.gross_iincome[x]==49.65:
        print(df.Customertype[x])
# Out:
# Member

# %%
df.gross_iincome.min()
# Out:
# 0.5085

# %%
for x in df.index:
    if df.gross_iincome[x] == 0.5085:
        print(df.InvoiceID[x])
# Out:
# 784-21-9238

# %%
x=df.Payment

# %%
x
# Out:
# 0          Ewallet
# 1             Cash
# 2      Credit card
# 3          Ewallet
# 4          Ewallet
#           ...
# 995        Ewallet
# 996        Ewallet
# 997           Cash
# 998           Cash
# 999           Cash
# Name: Payment, Length: 1000, dtype: object

# %%
y=df.gross_iincome

# %%
y
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3      23.2880
# 4      30.2085
#         ...
# 995     2.0175
# 996    48.6900
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Name: gross_iincome, Length: 1000, dtype: float64

# %%
plt.scatter(x,y)

# %%
x=df.Rating
x
# Out:
# 0      9.1
# 1      9.6
# 2      7.4
# 3      8.4
# 4      5.3
#       ...
# 995    6.2
# 996    4.4
# 997    7.7
# 998    4.1
# 999    6.6
# Name: Rating, Length: 1000, dtype: float64

# %%
y=df.	Unitprice

# %%
y
# Out:
# 0      74.69
# 1      15.28
# 2      46.33
# 3      58.22
# 4      86.31
#        ...
# 995    40.35
# 996    97.38
# 997    31.84
# 998    65.82
# 999    88.34
# Name: Unitprice, Length: 1000, dtype: float64

# %%
plt.scatter(x,y)

# %%
df.Rating.max()
# Out:
# 10.0

# %%
for x in df.index:
    if df.Rating[x]==10.0:
        print(df.Branch[x])
        print(df.City[x])
# Out:
# C
# Naypyitaw
# B
# Mandalay
# B
# Mandalay
# A
# Yangon
# B
# Mandalay

# %%
for x in df.index:
    if df.Rating[x]==10.0:
        print(df.Gender[x])
# Out:
# Female
# Female
# Male
# Female
# Female
