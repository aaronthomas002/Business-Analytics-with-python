# %%
import sqlite3

# %%
X = sqlite3.connect('SalesDBNEW.db')

# %%
X

# %%
Y=X.cursor()

# %%
Y.execute("select * from 'Supermarket_sales'")

# %%
new_list=[]

# %%
for k in Y.fetchall():
    new_list.append(int(k[16]))

# %%
new_list
# Out:
# [71,
#  5,
#  93,
#  11,
#  34,
#  88,
#  12,
#  96,
#  70,
#  0,
#  36,
#  81,
#  21,
#  45,
#  3,
#  1,
#  66,
#  53,
#  25,
#  42,
#  67,
#  4,
#  44,
#  90,
#  20,
#  4,
#  52,
#  16,
#  12,
#  1,
#  83,
#  77,
#  60,
#  84,
#  79,
#  88,
#  64,
#  56,
#  28,
#  94,
#  25,
#  71,
#  55,
#  63,
#  83,
#  56,
#  23,
#  60,
#  34,
#  63,
#  72,
#  80,
#  29,
#  36,
#  93,
#  16,
#  96,
#  86,
#  27,
#  64,
#  66,
#  85,
#  32,
#  22,
#  7,
#  19,
#  83,
#  12,
#  71,
#  58,
#  0,
#  1,
#  10,
#  32,
#  48,
#  40,
#  48,
#  58,
#  4,
#  27,
#  81,
#  2,
#  23,
#  98,
#  82,
#  20,
#  47,
#  36,
#  19,
#  51,
#  22,
#  16,
#  58,
#  38,
#  18,
#  50,
#  39,
#  95,
#  100,
#  26,
#  4,
#  97,
#  38,
#  26,
#  87,
#  33,
#  83,
#  2,
#  48,
#  25,
#  74,
#  28,
#  79,
#  21,
#  6,
#  79,
#  60,
#  35,
#  63,
#  92,
#  88,
#  17,
#  19,
#  31,
#  4,
#  68,
#  59,
#  98,
#  32,
#  15,
#  57,
#  86,
#  75,
#  3,
#  68,
#  85,
#  93,
#  69,
#  2,
#  12,
#  97,
#  64,
#  34,
#  36,
#  19,
#  52,
#  86,
#  0,
#  55,
#  25,
#  13,
#  99,
#  27,
#  63,
#  20,
#  73,
#  80,
#  54,
#  92,
#  52,
#  95,
#  100,
#  76,
#  79,
#  84,
#  33,
#  42,
#  17,
#  6,
#  5,
#  60,
#  83,
#  84,
#  48,
#  83,
#  24,
#  60,
#  19,
#  33,
#  6,
#  65,
#  56,
#  27,
#  30,
#  25,
#  69,
#  57,
#  66,
#  63,
#  10,
#  81,
#  65,
#  82,
#  18,
#  99,
#  1,
#  14,
#  64,
#  20,
#  84,
#  90,
#  54,
#  70,
#  73,
#  6,
#  35,
#  64,
#  24,
#  38,
#  16,
#  30,
#  15,
#  69,
#  18,
#  32,
#  68,
#  25,
#  0,
#  24,
#  57,
#  64,
#  94,
#  55,
#  30,
#  54,
#  30,
#  87,
#  73,
#  84,
#  18,
#  27,
#  25,
#  42,
#  49,
#  21,
#  55,
#  71,
#  40,
#  76,
#  84,
#  32,
#  37,
#  82,
#  76,
#  33,
#  7,
#  29,
#  72,
#  53,
#  90,
#  85,
#  82,
#  15,
#  65,
#  54,
#  9,
#  98,
#  50,
#  12,
#  7,
#  82,
#  65,
#  91,
#  67,
#  11,
#  67,
#  5,
#  74,
#  23,
#  18,
#  1,
#  24,
#  27,
#  39,
#  29,
#  28,
#  95,
#  90,
#  97,
#  31,
#  92,
#  34,
#  26,
#  28,
#  68,
#  31,
#  59,
#  64,
#  18,
#  86,
#  61,
#  23,
#  1,
#  54,
#  98,
#  64,
#  69,
#  73,
#  0,
#  69,
#  4,
#  23,
#  25,
#  31,
#  6,
#  88,
#  20,
#  75,
#  99,
#  75,
#  1,
#  97,
#  37,
#  8,
#  87,
#  68,
#  77,
#  41,
#  35,
#  7,
#  83,
#  56,
#  9,
#  52,
#  23,
#  9,
#  6,
#  39,
#  82,
#  17,
#  0,
#  49,
#  42,
#  57,
#  78,
#  23,
#  50,
#  10,
#  50,
#  92,
#  16,
#  58,
#  29,
#  6,
#  20,
#  88,
#  18,
#  19,
#  0,
#  3,
#  11,
#  43,
#  19,
#  36,
#  11,
#  71,
#  9,
#  56,
#  27,
#  66,
#  98,
#  44,
#  3,
#  89,
#  79,
#  67,
#  33,
#  47,
#  37,
#  21,
#  6,
#  21,
#  66,
#  21,
#  90,
#  27,
#  75,
#  64,
#  46,
#  54,
#  61,
#  31,
#  58,
#  20,
#  0,
#  26,
#  57,
#  41,
#  52,
#  21,
#  80,
#  35,
#  12,
#  90,
#  54,
#  12,
#  80,
#  50,
#  20,
#  84,
#  30,
#  98,
#  52,
#  56,
#  85,
#  12,
#  84,
#  20,
#  69,
#  87,
#  41,
#  41,
#  57,
#  20,
#  52,
#  52,
#  94,
#  77,
#  72,
#  45,
#  48,
#  99,
#  44,
#  12,
#  15,
#  39,
#  4,
#  81,
#  17,
#  62,
#  62,
#  48,
#  33,
#  20,
#  11,
#  79,
#  81,
#  29,
#  68,
#  8,
#  38,
#  45,
#  67,
#  87,
#  85,
#  36,
#  80,
#  35,
#  7,
#  69,
#  10,
#  7,
#  66,
#  10,
#  20,
#  11,
#  36,
#  96,
#  29,
#  15,
#  44,
#  66,
#  74,
#  56,
#  61,
#  83,
#  83,
#  58,
#  20,
#  86,
#  1,
#  35,
#  47,
#  76,
#  27,
#  81,
#  7,
#  10,
#  27,
#  87,
#  37,
#  66,
#  54,
#  94,
#  8,
#  12,
#  67,
#  83,
#  27,
#  52,
#  75,
#  29,
#  50,
#  96,
#  45,
#  80,
#  53,
#  30,
#  15,
#  37,
#  49,
#  73,
#  11,
#  93,
#  0,
#  49,
#  29,
#  32,
#  33,
#  45,
#  82,
#  14,
#  51,
#  73,
#  1,
#  77,
#  49,
#  32,
#  53,
#  59,
#  77,
#  37,
#  91,
#  72,
#  97,
#  80,
#  58,
#  36,
#  91,
#  97,
#  22,
#  100,
#  24,
#  32,
#  74,
#  18,
#  43,
#  37,
#  43,
#  74,
#  57,
#  71,
#  77,
#  61,
#  24,
#  49,
#  38,
#  74,
#  42,
#  80,
#  44,
#  65,
#  84,
#  61,
#  89,
#  67,
#  12,
#  92,
#  24,
#  83,
#  72,
#  78,
#  58,
#  53,
#  80,
#  11,
#  87,
#  29,
#  89,
#  19,
#  92,
#  20,
#  99,
#  92,
#  30,
#  44,
#  9,
#  83,
#  46,
#  58,
#  60,
#  74,
#  57,
#  95,
#  54,
#  59,
#  82,
#  43,
#  32,
#  14,
#  77,
#  18,
#  66,
#  8,
#  1,
#  90,
#  27,
#  28,
#  40,
#  77,
#  34,
#  9,
#  63,
#  65,
#  75,
#  67,
#  11,
#  32,
#  93,
#  83,
#  98,
#  61,
#  74,
#  83,
#  80,
#  20,
#  61,
#  64,
#  21,
#  15,
#  91,
#  63,
#  32,
#  65,
#  21,
#  39,
#  75,
#  32,
#  21,
#  39,
#  37,
#  61,
#  60,
#  87,
#  86,
#  63,
#  42,
#  70,
#  59,
#  46,
#  52,
#  33,
#  49,
#  61,
#  93,
#  69,
#  37,
#  14,
#  60,
#  55,
#  43,
#  35,
#  2,
#  45,
#  89,
#  76,
#  4,
#  39,
#  10,
#  1,
#  70,
#  50,
#  62,
#  90,
#  77,
#  43,
#  36,
#  13,
#  15,
#  24,
#  14,
#  68,
#  97,
#  20,
#  5,
#  11,
#  57,
#  18,
#  78,
#  77,
#  28,
#  39,
#  57,
#  64,
#  64,
#  83,
#  73,
#  35,
#  66,
#  40,
#  94,
#  35,
#  37,
#  71,
#  15,
#  86,
#  32,
#  86,
#  69,
#  45,
#  36,
#  57,
#  80,
#  15,
#  67,
#  49,
#  88,
#  66,
#  76,
#  26,
#  32,
#  53,
#  75,
#  6,
#  75,
#  73,
#  14,
#  42,
#  23,
#  12,
#  22,
#  96,
#  68,
#  88,
#  43,
#  7,
#  97,
#  3,
#  7,
#  73,
#  21,
#  6,
#  98,
#  11,
#  32,
#  14,
#  66,
#  36,
#  48,
#  28,
#  65,
#  26,
#  38,
#  29,
#  77,
#  98,
#  24,
#  61,
#  87,
#  28,
#  90,
#  100,
#  39,
#  23,
#  85,
#  54,
#  92,
#  8,
#  71,
#  98,
#  22,
#  51,
#  0,
#  43,
#  52,
#  57,
#  88,
#  48,
#  72,
#  52,
#  62,
#  28,
#  14,
#  72,
#  2,
#  34,
#  81,
#  87,
#  52,
#  52,
#  3,
#  68,
#  75,
#  5,
#  50,
#  3,
#  54,
#  65,
#  11,
#  33,
#  86,
#  30,
#  23,
#  36,
#  67,
#  58,
#  84,
#  100,
#  36,
#  85,
#  70,
#  8,
#  83,
#  41,
#  55,
#  40,
#  22,
#  61,
#  80,
#  15,
#  4,
#  96,
#  82,
#  33,
#  21,
#  35,
#  42,
#  8,
#  95,
#  77,
#  99,
#  19,
#  40,
#  21,
#  46,
#  9,
#  34,
#  90,
#  69,
#  79,
#  5,
#  90,
#  78,
#  61,
#  98,
#  0,
#  60,
#  69,
#  58,
#  53,
#  32,
#  80,
#  14,
#  39,
#  74,
#  49,
#  76,
#  55,
#  6,
#  86,
#  23,
#  63,
#  99,
#  22,
#  80,
#  16,
#  91,
#  92,
#  4,
#  54,
#  53,
#  38,
#  87,
#  74,
#  40,
#  22,
#  32,
#  99,
#  17,
#  49,
#  80,
#  5,
#  8,
#  37,
#  64,
#  39,
#  60,
#  46,
#  56,
#  48,
#  77,
#  62,
#  36,
#  86,
#  39,
#  72,
#  11,
#  85,
#  2,
#  6,
#  69,
#  4,
#  54,
#  0,
#  97,
#  61,
#  57,
#  72,
#  90,
#  23,
#  28,
#  47,
#  100,
#  94,
#  66,
#  73,
#  49,
#  71,
#  89,
#  10,
#  32,
#  45,
#  69,
#  20,
#  7,
#  24,
#  81,
#  23,
#  15,
#  61,
#  56,
#  21,
#  66,
#  98,
#  88,
#  78,
#  69,
#  13,
#  96,
#  62,
#  64,
#  3,
#  91,
#  25,
#  49,
#  47,
#  67,
#  23,
#  18,
#  0,
#  68,
#  30,
#  5,
#  79,
#  74,
#  95,
#  86,
#  31,
#  24,
#  11,
#  10,
#  38,
#  59,
#  72,
#  27,
#  85,
#  17,
#  57,
#  74,
#  68,
#  3,
#  82,
#  20,
#  20,
#  52,
#  16,
#  65,
#  61,
#  77,
#  53,
#  32,
#  40,
#  34,
#  26,
#  50,
#  86,
#  21,
#  58,
#  100,
#  87,
#  2,
#  56,
#  11,
#  0,
#  48,
#  82,
#  5,
#  71,
#  41,
#  30,
#  31,
#  79,
#  16,
#  28,
#  74,
#  68,
#  58,
#  58,
#  35,
#  47]

# %%
print("Maximum of Unitprice is = ",max(new_list))
print("Minimum of Unitprice is = ",min(new_list))
print("AVG of Unitprice is = ",sum(new_list)/len(new_list))
# Out:
# Maximum of Unitprice is =  100
# Minimum of Unitprice is =  0
# AVG of Unitprice is =  49.099

# %%
X.commit()

# %%
Y.close()

# %%
import sqlite3

# %%
X = sqlite3.connect('SalesDBNEW.db')

# %%
X

# %%
Y=X.cursor()

# %%
Y.execute("select * from 'Supermarket_sales'")

# %%
new_list=[]

# %%
for k in Y.fetchall():
    new_list.append(int(k[7]))

# %%
new_list
# Out:
# [7,
#  5,
#  7,
#  8,
#  7,
#  7,
#  6,
#  10,
#  2,
#  3,
#  4,
#  4,
#  5,
#  10,
#  10,
#  6,
#  7,
#  6,
#  3,
#  2,
#  5,
#  3,
#  2,
#  5,
#  3,
#  8,
#  1,
#  2,
#  5,
#  9,
#  5,
#  9,
#  8,
#  2,
#  4,
#  1,
#  5,
#  9,
#  8,
#  8,
#  1,
#  2,
#  6,
#  8,
#  2,
#  4,
#  9,
#  9,
#  6,
#  10,
#  7,
#  5,
#  4,
#  1,
#  2,
#  8,
#  2,
#  8,
#  10,
#  6,
#  3,
#  6,
#  9,
#  10,
#  4,
#  10,
#  2,
#  6,
#  10,
#  1,
#  10,
#  10,
#  3,
#  6,
#  9,
#  10,
#  9,
#  9,
#  10,
#  5,
#  6,
#  3,
#  8,
#  4,
#  5,
#  7,
#  5,
#  7,
#  1,
#  6,
#  4,
#  10,
#  7,
#  9,
#  1,
#  1,
#  10,
#  6,
#  3,
#  6,
#  1,
#  9,
#  9,
#  6,
#  7,
#  10,
#  6,
#  6,
#  9,
#  10,
#  2,
#  3,
#  7,
#  9,
#  9,
#  3,
#  5,
#  1,
#  10,
#  2,
#  8,
#  7,
#  9,
#  8,
#  8,
#  7,
#  5,
#  9,
#  8,
#  9,
#  7,
#  6,
#  4,
#  6,
#  6,
#  3,
#  5,
#  6,
#  10,
#  8,
#  10,
#  10,
#  10,
#  1,
#  6,
#  6,
#  10,
#  4,
#  8,
#  8,
#  4,
#  7,
#  9,
#  6,
#  8,
#  5,
#  1,
#  5,
#  9,
#  6,
#  8,
#  1,
#  7,
#  2,
#  10,
#  8,
#  10,
#  10,
#  6,
#  7,
#  5,
#  5,
#  8,
#  6,
#  8,
#  9,
#  8,
#  7,
#  6,
#  3,
#  7,
#  8,
#  10,
#  8,
#  7,
#  3,
#  8,
#  4,
#  1,
#  4,
#  3,
#  2,
#  9,
#  4,
#  5,
#  1,
#  2,
#  1,
#  4,
#  5,
#  6,
#  4,
#  7,
#  10,
#  5,
#  9,
#  9,
#  10,
#  3,
#  9,
#  9,
#  9,
#  5,
#  3,
#  7,
#  1,
#  5,
#  3,
#  8,
#  3,
#  6,
#  7,
#  5,
#  1,
#  2,
#  2,
#  9,
#  4,
#  6,
#  8,
#  2,
#  3,
#  9,
#  4,
#  10,
#  2,
#  5,
#  5,
#  5,
#  1,
#  9,
#  2,
#  2,
#  4,
#  8,
#  8,
#  3,
#  5,
#  4,
#  7,
#  9,
#  10,
#  2,
#  4,
#  8,
#  4,
#  1,
#  6,
#  4,
#  4,
#  9,
#  4,
#  4,
#  10,
#  1,
#  7,
#  4,
#  10,
#  4,
#  10,
#  5,
#  2,
#  9,
#  2,
#  6,
#  7,
#  10,
#  4,
#  10,
#  10,
#  8,
#  1,
#  1,
#  6,
#  4,
#  5,
#  1,
#  9,
#  7,
#  7,
#  10,
#  7,
#  1,
#  2,
#  10,
#  5,
#  4,
#  6,
#  4,
#  1,
#  2,
#  1,
#  1,
#  4,
#  8,
#  7,
#  7,
#  8,
#  3,
#  2,
#  6,
#  2,
#  5,
#  9,
#  10,
#  2,
#  3,
#  5,
#  7,
#  4,
#  9,
#  1,
#  6,
#  5,
#  6,
#  4,
#  5,
#  4,
#  4,
#  4,
#  9,
#  3,
#  5,
#  2,
#  5,
#  5,
#  9,
#  6,
#  3,
#  9,
#  3,
#  7,
#  7,
#  5,
#  3,
#  9,
#  1,
#  8,
#  7,
#  10,
#  10,
#  7,
#  7,
#  9,
#  1,
#  4,
#  10,
#  10,
#  3,
#  1,
#  8,
#  8,
#  2,
#  6,
#  4,
#  4,
#  9,
#  4,
#  10,
#  9,
#  7,
#  2,
#  6,
#  6,
#  5,
#  5,
#  9,
#  7,
#  4,
#  4,
#  4,
#  2,
#  5,
#  4,
#  5,
#  1,
#  6,
#  10,
#  9,
#  7,
#  3,
#  10,
#  1,
#  10,
#  1,
#  5,
#  5,
#  9,
#  6,
#  9,
#  6,
#  4,
#  1,
#  5,
#  7,
#  4,
#  5,
#  4,
#  4,
#  5,
#  10,
#  2,
#  5,
#  3,
#  8,
#  1,
#  4,
#  1,
#  2,
#  7,
#  3,
#  3,
#  10,
#  8,
#  1,
#  9,
#  7,
#  3,
#  5,
#  10,
#  2,
#  2,
#  6,
#  7,
#  1,
#  9,
#  4,
#  6,
#  4,
#  8,
#  5,
#  8,
#  9,
#  1,
#  7,
#  1,
#  10,
#  3,
#  1,
#  1,
#  6,
#  6,
#  5,
#  1,
#  4,
#  5,
#  9,
#  10,
#  10,
#  1,
#  5,
#  10,
#  4,
#  1,
#  5,
#  10,
#  7,
#  6,
#  1,
#  1,
#  6,
#  4,
#  10,
#  8,
#  5,
#  3,
#  5,
#  4,
#  10,
#  1,
#  8,
#  10,
#  5,
#  10,
#  10,
#  4,
#  10,
#  4,
#  1,
#  9,
#  2,
#  10,
#  8,
#  10,
#  2,
#  8,
#  2,
#  6,
#  1,
#  8,
#  1,
#  1,
#  2,
#  2,
#  1,
#  8,
#  3,
#  6,
#  5,
#  6,
#  7,
#  5,
#  7,
#  7,
#  7,
#  1,
#  5,
#  5,
#  2,
#  5,
#  3,
#  6,
#  6,
#  2,
#  6,
#  5,
#  4,
#  2,
#  10,
#  9,
#  6,
#  8,
#  10,
#  9,
#  5,
#  7,
#  1,
#  1,
#  4,
#  6,
#  3,
#  1,
#  4,
#  6,
#  1,
#  4,
#  10,
#  9,
#  5,
#  6,
#  3,
#  9,
#  9,
#  6,
#  7,
#  3,
#  2,
#  10,
#  6,
#  3,
#  9,
#  10,
#  8,
#  6,
#  2,
#  10,
#  10,
#  9,
#  7,
#  7,
#  5,
#  10,
#  7,
#  2,
#  5,
#  7,
#  4,
#  4,
#  4,
#  2,
#  3,
#  4,
#  2,
#  4,
#  3,
#  4,
#  3,
#  5,
#  10,
#  5,
#  6,
#  7,
#  1,
#  3,
#  3,
#  3,
#  3,
#  9,
#  5,
#  2,
#  1,
#  1,
#  10,
#  6,
#  7,
#  4,
#  7,
#  4,
#  1,
#  2,
#  1,
#  9,
#  3,
#  1,
#  10,
#  9,
#  6,
#  5,
#  6,
#  6,
#  3,
#  1,
#  7,
#  10,
#  1,
#  2,
#  2,
#  10,
#  3,
#  1,
#  10,
#  3,
#  2,
#  3,
#  3,
#  10,
#  7,
#  1,
#  5,
#  3,
#  3,
#  8,
#  2,
#  8,
#  5,
#  9,
#  6,
#  1,
#  2,
#  10,
#  5,
#  6,
#  10,
#  9,
#  4,
#  3,
#  1,
#  3,
#  5,
#  1,
#  3,
#  7,
#  6,
#  10,
#  2,
#  4,
#  3,
#  4,
#  6,
#  2,
#  10,
#  2,
#  3,
#  8,
#  10,
#  2,
#  7,
#  4,
#  10,
#  6,
#  1,
#  1,
#  6,
#  2,
#  6,
#  2,
#  2,
#  10,
#  2,
#  3,
#  9,
#  7,
#  10,
#  7,
#  9,
#  5,
#  4,
#  4,
#  9,
#  10,
#  8,
#  3,
#  10,
#  9,
#  9,
#  7,
#  4,
#  1,
#  8,
#  3,
#  6,
#  4,
#  9,
#  9,
#  8,
#  5,
#  7,
#  3,
#  3,
#  6,
#  7,
#  9,
#  3,
#  7,
#  4,
#  8,
#  3,
#  10,
#  4,
#  7,
#  4,
#  3,
#  1,
#  7,
#  1,
#  10,
#  7,
#  10,
#  8,
#  9,
#  7,
#  1,
#  2,
#  2,
#  8,
#  1,
#  10,
#  5,
#  9,
#  7,
#  4,
#  5,
#  10,
#  5,
#  3,
#  8,
#  8,
#  6,
#  10,
#  4,
#  10,
#  10,
#  8,
#  5,
#  4,
#  8,
#  3,
#  6,
#  4,
#  6,
#  4,
#  7,
#  7,
#  1,
#  2,
#  5,
#  7,
#  1,
#  5,
#  9,
#  8,
#  4,
#  1,
#  8,
#  5,
#  7,
#  8,
#  5,
#  3,
#  7,
#  1,
#  4,
#  10,
#  7,
#  2,
#  2,
#  1,
#  10,
#  1,
#  5,
#  6,
#  8,
#  7,
#  9,
#  9,
#  4,
#  2,
#  4,
#  1,
#  10,
#  8,
#  10,
#  5,
#  1,
#  8,
#  8,
#  7,
#  8,
#  4,
#  5,
#  4,
#  2,
#  1,
#  3,
#  7,
#  4,
#  9,
#  3,
#  10,
#  10,
#  8,
#  4,
#  8,
#  1,
#  7,
#  1,
#  5,
#  6,
#  10,
#  6,
#  3,
#  1,
#  2,
#  2,
#  1,
#  3,
#  1,
#  1,
#  9,
#  6,
#  1,
#  2,
#  7,
#  10,
#  5,
#  9,
#  8,
#  4,
#  6,
#  9,
#  1,
#  2,
#  9,
#  7,
#  3,
#  3,
#  8,
#  2,
#  3,
#  4,
#  7,
#  1,
#  10,
#  6,
#  4,
#  8,
#  1,
#  1,
#  8,
#  8,
#  10,
#  8,
#  10,
#  6,
#  2,
#  7,
#  1,
#  10,
#  8,
#  10,
#  5,
#  8,
#  5,
#  5,
#  6,
#  8,
#  7,
#  6,
#  7,
#  9,
#  9,
#  4,
#  5,
#  7,
#  2,
#  4,
#  10,
#  5,
#  2,
#  10,
#  3,
#  4,
#  8,
#  8,
#  3,
#  6,
#  1,
#  4,
#  3,
#  3,
#  9,
#  6,
#  2,
#  7,
#  6,
#  4,
#  1,
#  9,
#  9,
#  2,
#  6,
#  2,
#  10,
#  7,
#  6,
#  3,
#  7,
#  5,
#  3,
#  6,
#  4,
#  9,
#  10,
#  5,
#  7,
#  7,
#  2,
#  1,
#  5,
#  8,
#  3,
#  3,
#  4,
#  4,
#  6,
#  7,
#  9,
#  6,
#  10,
#  9,
#  1,
#  2,
#  1,
#  3,
#  2,
#  2,
#  9,
#  3,
#  3,
#  5,
#  10,
#  7,
#  7,
#  3,
#  2,
#  2,
#  4,
#  6,
#  1,
#  1,
#  4,
#  4,
#  9,
#  7,
#  7,
#  5,
#  2,
#  8,
#  10,
#  8,
#  5,
#  10,
#  2,
#  10,
#  1,
#  1,
#  10,
#  1,
#  1,
#  7]

# %%
print("Maximum of Unitprice is = ",max(new_list))
print("Minimum of Unitprice is = ",min(new_list))
print("AVG of Unitprice is = ",sum(new_list)/len(new_list))
# Out:
# Maximum of Unitprice is =  10
# Minimum of Unitprice is =  1
# AVG of Unitprice is =  5.51

# %%
X.commit()

# %%
Y.close()

# %%
import sqlite3

# %%
X = sqlite3.connect('SalesDBNEW.db')

# %%
X

# %%
Y=X.cursor()

# %%
Y.execute("SELECT * FROM Supermarket_sales WHERE Productline='Health and beauty'")

# %%
new_list=[]

# %%
for k in Y.fetchall():
    new_list.append(int(k[7]))

# %%
new_list
# Out:
# [7,
#  8,
#  2,
#  10,
#  7,
#  3,
#  9,
#  2,
#  8,
#  2,
#  9,
#  8,
#  4,
#  10,
#  2,
#  1,
#  5,
#  6,
#  6,
#  9,
#  1,
#  10,
#  7,
#  3,
#  6,
#  10,
#  10,
#  6,
#  4,
#  8,
#  9,
#  8,
#  5,
#  3,
#  8,
#  2,
#  4,
#  10,
#  9,
#  9,
#  9,
#  10,
#  5,
#  2,
#  2,
#  6,
#  6,
#  4,
#  5,
#  10,
#  1,
#  9,
#  7,
#  4,
#  1,
#  6,
#  4,
#  7,
#  7,
#  10,
#  10,
#  1,
#  5,
#  6,
#  10,
#  5,
#  1,
#  1,
#  2,
#  7,
#  1,
#  1,
#  1,
#  7,
#  8,
#  3,
#  8,
#  5,
#  5,
#  2,
#  6,
#  1,
#  9,
#  4,
#  2,
#  4,
#  4,
#  5,
#  6,
#  3,
#  10,
#  10,
#  7,
#  6,
#  6,
#  4,
#  6,
#  3,
#  8,
#  10,
#  10,
#  9,
#  7,
#  9,
#  5,
#  8,
#  3,
#  10,
#  7,
#  5,
#  4,
#  7,
#  7,
#  8,
#  5,
#  5,
#  3,
#  4,
#  1,
#  1,
#  8,
#  4,
#  3,
#  9,
#  4,
#  1,
#  7,
#  5,
#  6,
#  3,
#  2,
#  5,
#  8,
#  7,
#  5,
#  2,
#  10,
#  5,
#  9,
#  7,
#  7,
#  3,
#  5,
#  7,
#  3,
#  3,
#  4,
#  7,
#  2,
#  8,
#  8,
#  1]

# %%
print("Maximum of Quantity with Health and Beauty is = ",max(new_list))  

print("Minimum of Quantity with Health and Beauty = ",min(new_list))  

print("Average of Quantity with Health and Beauty = ",sum(new_list)/len(new_list))
# Out:
# Maximum of Quantity with Health and Beauty is =  10
# Minimum of Quantity with Health and Beauty =  1
# Average of Quantity with Health and Beauty =  5.618421052631579

# %%
X.commit()

# %%
Y.close()

# %%
import sqlite3

# %%
X = sqlite3.connect('SalesDBNEW.db')

# %%
Y=X.cursor()

# %%
Y.execute("SELECT * FROM Supermarket_sales WHERE Productline='Health and beauty'")

# %%
new_list=[]

# %%
for k in Y.fetchall():
    new_list.append(int(k[16]))

# %%
new_list
# Out:
# [71,
#  11,
#  70,
#  3,
#  66,
#  4,
#  1,
#  84,
#  28,
#  83,
#  23,
#  86,
#  7,
#  19,
#  83,
#  58,
#  27,
#  81,
#  51,
#  38,
#  18,
#  39,
#  87,
#  28,
#  68,
#  64,
#  34,
#  52,
#  0,
#  25,
#  92,
#  33,
#  60,
#  6,
#  30,
#  14,
#  20,
#  73,
#  35,
#  87,
#  42,
#  21,
#  71,
#  37,
#  24,
#  29,
#  28,
#  68,
#  31,
#  98,
#  23,
#  8,
#  35,
#  7,
#  56,
#  9,
#  82,
#  58,
#  29,
#  3,
#  41,
#  54,
#  12,
#  20,
#  41,
#  57,
#  52,
#  77,
#  72,
#  4,
#  36,
#  7,
#  10,
#  83,
#  76,
#  81,
#  50,
#  33,
#  49,
#  72,
#  22,
#  71,
#  84,
#  46,
#  58,
#  74,
#  59,
#  14,
#  77,
#  90,
#  32,
#  63,
#  42,
#  37,
#  35,
#  13,
#  15,
#  97,
#  20,
#  78,
#  37,
#  15,
#  49,
#  6,
#  73,
#  7,
#  6,
#  14,
#  28,
#  43,
#  52,
#  28,
#  81,
#  3,
#  50,
#  65,
#  11,
#  30,
#  36,
#  80,
#  4,
#  95,
#  21,
#  34,
#  90,
#  61,
#  99,
#  80,
#  4,
#  22,
#  99,
#  69,
#  61,
#  90,
#  100,
#  66,
#  49,
#  71,
#  13,
#  25,
#  67,
#  18,
#  79,
#  74,
#  10,
#  77,
#  56,
#  0,
#  5,
#  71,
#  30,
#  68]

# %%
print("Maximum of unitprice with Health and Beauty is = ",max(new_list))  

print("Minimum of  unitprice with Health and Beauty = ",min(new_list))  

print("Average of  unitprice with Health and Beauty = ",sum(new_list)/len(new_list))
# Out:
# Maximum of unitprice with Health and Beauty is =  100
# Minimum of  unitprice with Health and Beauty =  0
# Average of  unitprice with Health and Beauty =  45.35526315789474

# %%
import sqlite3

# %%
X = sqlite3.connect('SalesDBNEW.db')

# %%
Y=X.cursor()

# %%
Y.execute("SELECT * FROM Supermarket_sales WHERE Productline='Electronic accessories'")

# %%
new_list=[]

# %%
for k in Y.fetchall():
    new_list.append(int(k[7]))

# %%
new_list
# Out:
# [5,
#  7,
#  6,
#  4,
#  5,
#  5,
#  5,
#  9,
#  4,
#  6,
#  8,
#  6,
#  6,
#  10,
#  1,
#  6,
#  9,
#  10,
#  10,
#  8,
#  6,
#  5,
#  1,
#  8,
#  6,
#  5,
#  4,
#  7,
#  9,
#  9,
#  9,
#  3,
#  6,
#  5,
#  4,
#  6,
#  3,
#  5,
#  3,
#  4,
#  1,
#  4,
#  4,
#  9,
#  10,
#  7,
#  1,
#  5,
#  4,
#  4,
#  8,
#  7,
#  3,
#  10,
#  5,
#  4,
#  5,
#  3,
#  3,
#  1,
#  7,
#  7,
#  1,
#  3,
#  9,
#  9,
#  7,
#  4,
#  2,
#  1,
#  9,
#  7,
#  3,
#  6,
#  8,
#  6,
#  6,
#  4,
#  10,
#  10,
#  1,
#  5,
#  4,
#  1,
#  10,
#  2,
#  8,
#  7,
#  3,
#  10,
#  6,
#  6,
#  6,
#  7,
#  9,
#  8,
#  6,
#  1,
#  1,
#  5,
#  3,
#  1,
#  8,
#  2,
#  5,
#  10,
#  5,
#  3,
#  1,
#  10,
#  1,
#  9,
#  4,
#  9,
#  3,
#  7,
#  10,
#  8,
#  10,
#  8,
#  10,
#  4,
#  9,
#  7,
#  8,
#  7,
#  2,
#  8,
#  9,
#  4,
#  10,
#  1,
#  8,
#  4,
#  10,
#  10,
#  8,
#  10,
#  1,
#  3,
#  1,
#  10,
#  3,
#  10,
#  1,
#  8,
#  8,
#  10,
#  8,
#  5,
#  6,
#  9,
#  4,
#  6,
#  3,
#  4,
#  9,
#  7,
#  2,
#  6,
#  2,
#  3,
#  2,
#  5,
#  7,
#  1,
#  7,
#  10,
#  2,
#  1]

# %%
print("Maximum of Quantity with Electronic accessories is = ",max(new_list))  

print("Minimum of Quantity with Electronic accessories = ",min(new_list))  

print("Average of Quantity with Electronic accessories = ",sum(new_list)/len(new_list))
# Out:
# Maximum of Quantity with Electronic accessories is =  10
# Minimum of Quantity with Electronic accessories =  1
# Average of Quantity with Electronic accessories =  5.711764705882353

# %%
X.commit()

# %%
Y.close()

# %%
import sqlite3

# %%
X = sqlite3.connect('SalesDBNEW.db')

# %%
Y=X.cursor()

# %%
Y.execute("SELECT * FROM Supermarket_sales WHERE Gender = 'Male' AND Productline = 'Health and beauty'")

# %%
new_list=[]

# %%
for k in Y.fetchall():
    new_list.append(int(k[7]))

# %%
len(new_list)
# Out:
# 88

# %%
X.commit()

# %%
Y.close()

# %%
import sqlite3

# %%
X = sqlite3.connect('SalesDBNEW.db')

# %%
Y=X.cursor()

# %%
Y.execute("SELECT * FROM Supermarket_sales WHERE Gender = 'Female' AND Productline = 'Electronic accessories'")

# %%
new_list=[]

# %%
for k in Y.fetchall():
    new_list.append(int(k[7]))

# %%
len(new_list)
# Out:
# 84

# %%
X.commit()

# %%
Y.close()

# %%
import sqlite3

# %%
X = sqlite3.connect('SalesDBNEW.db')

# %%
Y=X.cursor()

# %%
Y.execute("SELECT * FROM Supermarket_sales WHERE Gender = 'Female' AND (Productline = 'Electronic accessories'or 'Sports and travel')")

# %%
new_list=[]

# %%
for k in Y.fetchall():
    new_list.append(int(k[7]))

# %%
len(new_list)
# Out:
# 84

# %%
X.commit()

# %%
Y.close()

# %%
import sqlite3

# %%
X = sqlite3.connect('SalesDBNEW.db')

# %%
Y=X.cursor()

# %%
Y.execute("select * from 'Supermarket_sales'")

# %%
tax_value=[]

# %%
for k in Y.fetchall():
    tax_value.append(int(k[8]))

# %%
len(tax_value)
# Out:
# 1000

# %%
Y.execute("select * from 'Supermarket_sales'")

# %%
qt=[]

# %%
for k in Y.fetchall():
    qt.append(int(k[7]))

# %%
len(qt)
# Out:
# 1000

# %%
import matplotlib.pyplot as plt
plt.scatter(qt,tax_value)

# %%
X.commit()

# %%
Y.close()

# %%
import sqlite3

# %%
X = sqlite3.connect('SalesDBNEW.db')

# %%
Y=X.cursor()

# %%
new_list=[]

# %%
Y.execute("SELECT * FROM Supermarket_sales WHERE City='Yangon'")

# %%
for k in Y.fetchall():
    new_list.append(int(k[7]))

# %%
sum(new_list)
# Out:
# 1859

# %%
Y.execute("SELECT * FROM Supermarket_sales WHERE City='Yangon'")

# %%
new_data=[]

# %%
Y.execute("SELECT * FROM Supermarket_sales WHERE City='Mandalay'")

# %%
for k in Y.fetchall():
    new_data.append(int(k[7]))

# %%
sum(new_data)
# Out:
# 1820

# %%
X.commit()

# %%
Y.close()

# %%
import sqlite3

# %%
X = sqlite3.connect('SalesDBNEW.db')

# %%
Y=X.cursor()

# %%
Y.execute("SELECT * FROM Supermarket_sales WHERE City='Yangon'")

# %%
new_list=[]

# %%
for k in Y.fetchall():
    new_list.append(int(k[8]))

# %%
sum(new_list)
# Out:
# 171812
